# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
# load text
filename = 'raw\wiki_raw.txt'
file = open(filename, 'rt', encoding="utf-8")
text = file.read()
file.close()

# %%
tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize(text)

# %%
words = [word for word in tokens if word.isalpha()]
print(words[:100])
# Out:
# ['ազատ', 'հանրագիտարանից', 'Jump', 'to', 'navigationJump', 'to', 'search', 'HS', 'Անվան', 'այլ', 'կիրառումների', 'համար', 'Հայաստան', 'այլ', 'կիրառումներ', 'Արեւմտահայերէն', 'Հայաստան', 'արեւմտահայերէն', 'Այս', 'հոդվածն', 'ունի', 'ձայնային', 'տարբերակ', 'Լսել', 'հոդվածի', 'ներածությունը', 'Ձայնային', 'ֆայլն', 'ստեղծվել', 'է', 'հետևյալ', 'տարբերակի', 'հիման', 'վրա', 'Սեպտեմբերի', 'և', 'չի', 'պարունակում', 'այս', 'ամսաթվից', 'հետո', 'կատարված', 'Տես', 'նաև', 'ֆայլի', 'մասին', 'տեղեկությունները', 'կամ', 'բեռնիր', 'ձայնագրությունը', 'Գտնել', 'այլ', 'աուդիո', 'հոդվածներ', 'Հայաստանի', 'Հանրապետություն', 'Հայաստան', 'դրոշ', 'Դրոշ', 'Հայաստան', 'զինանշանը', 'Զինանշան', 'Մեր', 'հայրենիք', 'Հայաստան', 'դիրքը', 'Մայրաքաղաք', 'Երևան', 'Ամենամեծ', 'քաղաք', 'մայրաքաղաք', 'պետական', 'լեզու', 'հայերեն', 'Էթնիկ', 'խմբեր', 'Հունիս', 'հայեր', 'եզդիներ', 'ռուսներ', 'այլ', 'Կառավարում', 'Խորհրդարանական', 'նախագահ', 'Արմեն', 'Սարգսյան', 'վարչապետ', 'Նիկոլ', 'Փաշինյան', 'հիմնադրում', 'և', 'անկախացում', 'ավանդական', 'տարեթիվ', 'Վանի', 'թագավորություն', 'Երվանդունիների', 'թագավորություն', 'Արտաշեսյանների', 'թագավորություն', 'Արշակունիների', 'թագավորություն', 'Բագրատունիների', 'թագավորություն', 'Կիլիկյան', 'Հայաստան', 'Զաքարյան', 'իշխանապետություն', 'Հայաստանի', 'Հանրապետություն', 'Տարածք', 'Ընդհանուր', 'Ջրային', 'Բնակչություն', 'նախահաշիվը', 'մարդահամարը', 'decrease', 'Խտություն', 'ՀՆԱ', 'ԳՀ', 'գնահատում', 'Ընդհանուր', 'միլիարդ', 'միլիոն', 'Մեկ', 'շնչի', 'հաշվով', 'ՀՆԱ', 'անվանական', 'գնահատում', 'Ընդհանուր', 'միլիարդ', 'միլիոն', 'Մեկ', 'շնչի', 'հաշվով', 'Ջինի', 'ՄԶՀ', 'Արժույթ', 'դրամ', 'AMD', 'Ժամային', 'գոտի', 'UTC', 'Ազգային', 'դոմեն', 'և', 'Հեռախոսային', 'կոդ', 'Հայաստան', 'պաշտոնական', 'Հայաստանի', 'Հանրապետություն', 'պետություն', 'Հարավային', 'Գտնվում', 'է', 'Առաջավոր', 'Ասիայի', 'հյուսիսային', 'Հայկական', 'լեռնաշխարհի', 'Հյուսիսում', 'սահմանակցում', 'է', 'Վրաստանին', 'Ադրբեջանին', 'Իրանին', 'Հարավարևելյան', 'կողմում', 'Արցախն', 'է', 'Ն', 'իսկ', 'հարավարևմտյան', 'Ադրբեջանի', 'վերահսկողության', 'տակ', 'գտնվող', 'Նախիջևանի', 'Ինքնավար', 'Այժմյան', 'Հայաստանը', 'զբաղեցնում', 'է', 'պատմական', 'Հայաստանի', 'տարածքի', 'միայն', 'մեկ', 'տասներորդը', 'Մինչև', 'դարի', 'սկիզբը', 'Հայաստան', 'անվանումը', 'վերաբերում', 'էր', 'ողջ', 'Հայկական', 'լեռնաշխարհին', 'որտեղ', 'կազմավորվել', 'և', 'իր', 'պատմական', 'ուղին', 'է', 'անցել', 'հայ', 'Ըստ', 'պատմիչ', 'Մովսես', 'հայ', 'ժողովրդի', 'պատմության', 'սկիզբն', 'է', 'համարվում', 'թվականը', 'երբ', 'հայ', 'ժողովրդի', 'անվանադիր', 'Հայկ', 'նահապետը', 'Հայոց', 'ձորում', 'հաղթում', 'է', 'Ասորեստանի', 'թագավոր', 'Բելին', 'և', 'անկախություն', 'նվաճում', 'Ժամանակակից', 'Հայաստանը', 'զբաղեցնում', 'է', 'տարածք', 'աշխարհում', 'և', 'ունի', 'մարդ', 'բնակչություն', 'աշխարհում', 'Մայրաքաղաքը', 'Երևանն', 'է', 'պետական', 'հայերենը', 'բնակչության', 'տոկոսը', 'դավանում', 'է', 'քրիստոնեություն', 'Հայաստանյայց', 'Առաքելական', 'Սուրբ', 'Եկեղեցին', 'ժամանակակից', 'Հայաստանի', 'հիմնական', 'կրոնական', 'հաստատությունն', 'է', 'Հայաստանն', 'ունիտար', 'կառուցվածքով', 'բազմակուսակցական', 'համակարգով', 'ժողովրդավարական', 'ազգային', 'պետություն', 'Հայաստանի', 'Սահմանադրությունն', 'ընդունվել', 'է', 'թվականի', 'հուլիսի', 'և', 'փոփոխությունների', 'ենթարկվել', 'թվականի', 'նոյեմբերի', 'ու', 'թվականի', 'դեկտեմբերի', 'համապետական', 'հանրաքվեների', 'Վանի', 'թագավորությունը', 'հիմնվել', 'է', 'թվականին', 'որին', 'VI', 'դարում', 'փոխարինել', 'է', 'Սատրապական', 'I', 'Տիգրան', 'Մեծի', 'օրոք', 'Մեծ', 'Հայքը', 'հասնում', 'է', 'իր', 'առավելագույն', 'մեծությանը', 'և', 'Հայաստանն', 'առաջին', 'պետությունն', 'է', 'որ', 'ընդունել', 'է', 'քրիստոնեությունը', 'որպես', 'պետական', 'կրոն', 'III', 'դարից', 'մինչև', 'վաղ', 'IV', 'դարն', 'ընկած', 'ժամանակահատվածում', 'Քրիստոնեությունը', 'որպես', 'պետական', 'կրոն', 'է', 'ընդունվել', 'թվականին', 'Հին', 'հայկական', 'թագավորությունը', 'վաղ', 'V', 'դարում', 'բաժանվել', 'է', 'Բյուզանդիայի', 'և', 'Սասանյան', 'Պարսկաստանի', 'Բագրատունիների', 'կառավարման', 'IX', 'դարում', 'Հայաստանը', 'վերականգնել', 'է', 'իր', 'Բյուզանդիայի', 'դեմ',  ...
